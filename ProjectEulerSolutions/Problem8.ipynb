# %% [markdown]
# ## Problem Statement:
#
# The four adjacent digits in the $1000$-digit number that have the greatest product are $9 \times 9 \times 8 \times 9 = 5832$.
# <p class="monospace center">
# 73167176531330624919225119674426574742355349194934<br>
# 96983520312774506326239578318016984801869478851843<br>
# 85861560789112949495459501737958331952853208805511<br>
# 12540698747158523863050715693290963295227443043557<br>
# 66896648950445244523161731856403098711121722383113<br>
# 62229893423380308135336276614282806444486645238749<br>
# 30358907296290491560440772390713810515859307960866<br>
# 70172427121883998797908792274921901699720888093776<br>
# 65727333001053367881220235421809751254540594752243<br>
# 52584907711670556013604839586446706324415722155397<br>
# 53697817977846174064955149290862569321978468622482<br>
# 83972241375657056057490261407972968652414535100474<br>
# 82166370484403199890008895243450658541227588666881<br>
# 16427171479924442928230863465674813919123162824586<br>
# 17866458359124566529476545682848912883142607690042<br>
# 24219022671055626321111109370544217506941658960408<br>
# 07198403850962455444362981230987879927244284909188<br>
# 84580156166097919133875499200524063689912560717606<br>
# 05886116467109405077541002256983155200055935729725<br>
# 71636269561882670428252483600823257530420752963450<br></p>
#
# Find the thirteen adjacent digits in the $1000$-digit number that have the greatest product. What is the value of this product?
#
# ## Thought Process:
#
# This problem seems to require a simple solution of starting from the first digit (from the left) and calculating the product of the consecutive 13 adjacent digits until one reaches the final 13 adjacent digits. To ensure one finds the largest product, one can define a variable `greatest_product` which is updated each time one calculates a product of the 13 adjacent digits that is greater than the current value of the variable `greatest_product`. At the end of this iterative process, the value of the variable `greatest_product` will be the greatest product from $13$ adjacent digits in the $1000$-digit number.
#
# ## Solution:

# %%
def GreatestProduct(a,n):
    f'Function to return the greatest product of {a} adjacent digits in {n}' 
    array_of_digits_of_n = [int(digits) for digits in f'{n}']
    greatest_product = 0
    product = 1
    for i in range(len(array_of_digits_of_n)+1-a):
        for digits in array_of_digits_of_n[i:i+a]:
            product *= digits 
        if product>greatest_product:
            greatest_product = product
            product = 1
        else:
            product = 1
    return greatest_product

print(f"The greatest product from thirteen adjacent digits of the 1000-digit number ... \n = {GreatestProduct(13,...)}")
# Out:
# The greatest product from thirteen adjacent digits of the 1000-digit number ...
#  = 23514624000
